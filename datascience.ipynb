# %% [markdown]
# <a href="https://colab.research.google.com/github/SachiSachu/Python/blob/main/datascience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make  ... horsepower-binned diesel gas
# 0          3                122  alfa-romero  ...            Medium      0   1
# 1          3                122  alfa-romero  ...            Medium      0   1
# 2          1                122  alfa-romero  ...            Medium      0   1
# 3          2                164         audi  ...            Medium      0   1
# 4          2                164         audi  ...            Medium      0   1
#
# [5 rows x 29 columns]

# %%
#to calculate the overall normalized losses
df['normalized-losses'].sum()//len(df['normalized-losses'])
# Out:
# 122

# %%
df['curb-weight'].max()
# Out:
# 4066

# %%
df['curb-weight'].sum()//len(df['curb-weight'])
# Out:
# 2555

# %%
df['curb-weight'].min()
# Out:
# 1488

# %%
for door in df['num-of-doors'].unique():
  print(door,":",len(df[df['num-of-doors']==door]))
# Out:
# two : 86
# four : 115

# %%
for dw in df['drive-wheels'].unique():
  print(dw,":",len(df[df['drive-wheels']==dw]))
# Out:
# rwd : 75
# fwd : 118
# 4wd : 8

# %%
for el in df['engine-location'].unique():
  print(el,":",len(df[df['engine-location']==el]))
# Out:
# front : 198
# rear : 3

# %%
for wb in df['wheel-base'].unique():
  print(wb,":",len(df[df['wheel-base']==wb]))
# Out:
# 88.6 : 2
# 94.5 : 19
# 99.8 : 2
# 99.4 : 1
# 105.8 : 3
# 101.2 : 4
# 103.5 : 3
# 110.0 : 3
# 88.4 : 1
# 93.7 : 20
# 103.3 : 2
# 95.9 : 5
# 86.6 : 2
# 96.5 : 8
# 94.3 : 1
# 96.0 : 1
# 113.0 : 2
# 102.0 : 1
# 93.1 : 5
# 95.3 : 4
# 98.8 : 6
# 104.9 : 2
# 106.7 : 1
# 115.6 : 2
# 96.6 : 1
# 120.9 : 1
# 112.0 : 1
# 102.7 : 1
# 93.0 : 1
# 96.3 : 6
# 95.1 : 1
# 97.2 : 5
# 100.4 : 6
# 91.3 : 2
# 99.2 : 1
# 107.9 : 6
# 114.2 : 4
# 108.0 : 1
# 89.5 : 3
# 96.1 : 2
# 99.1 : 6
# 93.3 : 1
# 97.0 : 4
# 96.9 : 2
# 95.7 : 13
# 98.4 : 6
# 102.4 : 5
# 102.9 : 2
# 104.5 : 2
# 97.3 : 7
# 104.3 : 6
# 109.1 : 5

# %%
for hp in df['horsepower'].unique():
  print(hp,":",len(df[df['horsepower']==hp]))
# Out:
# 111.0 : 4
# 154.0 : 1
# 102.0 : 5
# 115.0 : 1
# 110.0 : 8
# 140.0 : 1
# 101.0 : 6
# 121.0 : 3
# 182.0 : 3
# 48.0 : 1
# 70.0 : 9
# 68.0 : 19
# 88.0 : 6
# 145.0 : 5
# 58.0 : 1
# 76.0 : 5
# 60.0 : 1
# 86.0 : 4
# 100.0 : 2
# 78.0 : 1
# 90.0 : 3
# 176.0 : 2
# 262.0 : 1
# 135.0 : 1
# 84.0 : 5
# 64.0 : 1
# 120.0 : 1
# 72.0 : 1
# 123.0 : 4
# 155.0 : 2
# 184.0 : 2
# 175.0 : 1
# 116.0 : 9
# 69.0 : 10
# 55.0 : 1
# 97.0 : 5
# 152.0 : 3
# 160.0 : 5
# 200.0 : 1
# 95.0 : 7
# 142.0 : 1
# 143.0 : 1
# 207.0 : 3
# 104.256157635468 : 2
# 73.0 : 3
# 82.0 : 5
# 94.0 : 2
# 62.0 : 6
# 56.0 : 2
# 112.0 : 2
# 92.0 : 4
# 161.0 : 2
# 156.0 : 2
# 52.0 : 2
# 85.0 : 3
# 114.0 : 6
# 162.0 : 2
# 134.0 : 1
# 106.0 : 1

# %%
df
# Out:
#      symboling  normalized-losses         make  ... horsepower-binned diesel gas
# 0            3                122  alfa-romero  ...            Medium      0   1
# 1            3                122  alfa-romero  ...            Medium      0   1
# 2            1                122  alfa-romero  ...            Medium      0   1
# 3            2                164         audi  ...            Medium      0   1
# 4            2                164         audi  ...            Medium      0   1
# ..         ...                ...          ...  ...               ...    ...  ..
# 196         -1                 95        volvo  ...            Medium      0   1
# 197         -1                 95        volvo  ...              High      0   1
# 198         -1                 95        volvo  ...            Medium      0   1
# 199         -1                 95        volvo  ...            Medium      1   0
# 200         -1                 95        volvo  ...            Medium      0   1
#
# ...
